# %%
print("hello world")
# Out:
# hello world

# %%
#add above ->A, below-> B del->x

# %%
add above ->A, below-> B del->x
# Out:
#   Cell In[3], line 1
#     add above ->A, below-> B del->x
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Identifierss

# %%
num = 56

# %%
num1 = 8

# %%
name = "shivam"

# %%
print(name)
# Out:
# shivam

# %%
name
# Out:
# 'shivam'

# %%
rate of interest = 5
# Out:
#   Cell In[10], line 1
#     rate of interest = 5
#          ^
# SyntaxError: invalid syntax

# %%
rate_of_interest=5.8

# %%
rate_of_interest
# Out:
# 5.8

# %%
pass = 28
# Out:
#   Cell In[13], line 1
#     pass = 28
#          ^
# SyntaxError: invalid syntax

# %%
Pass =2

# %%
Pass
# Out:
# 2

# %%
l=[3]

# %%
type(l)
# Out:
# list

# %%
i=5

# %%
s="string"

# %%
f=0.5

# %%
b=True

# %%
type(b)
# Out:
# bool

# %%
num =12

num2 =78.44

name ="shivam"

# %%
type(num)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
c=8+6j

# %%
type(c)
# Out:
# complex

# %%
num=2133567898754223 **234
num
# Out:
# ...

# %%
#float

# %%
num =23e4

# %%
type(num)
# Out:
# float

# %%
num
# Out:
# 230000.0

# %%
# string

# %%
sent = "I like Python Programming"

# %%
print(sent)
# Out:
# I like Python Programming

# %%
# I like "Python" Programming
#I like 'Python' Programming

# %%
sent ='I like "Python" Programming'
print(sent)
# Out:
# I like "Python" Programming

# %%
sent ="I like 'Python' Programming"
print(sent)
# Out:
# I like 'Python' Programming

# %%
num1=12
num2=34
result= num1+num2
print(result)
# Out:
# 46

# %%
print(10+23)
# Out:
# 33

# %%
a=3;b=5;z=a+b;print(z);
# Out:
# 8

# %%
a,b,c=23,56,"ok"

# %%
a
# Out:
# 23

# %%
b
# Out:
# 56

# %%
c
# Out:
# 'ok'
