# %%
#string functions

# %%
name = "Shivam"

# %%
name.lower()
# Out:
# 'shivam'

# %%
name
# Out:
# 'Shivam'

# %%
name = name.lower()

# %%
name
# Out:
# 'shivam'

# %%
name.upper()
# Out:
# 'SHIVAM'

# %%
name.title()
# Out:
# 'Shivam'

# %%
name = "Shivam"

# %%
name.swapcase()
# Out:
# 'sHIVAM'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2= "123"
name3 ="ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name2.isalnum()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name3.isalnum()
# Out:
# True

# %%
n="l&"

# %%
n.isalnum()
# Out:
# False

# %%
name = " pune "

# %%
print(name)
# Out:
#  pune

# %%
name.startswith("P")
# Out:
# False

# %%
name.startswith(" p")
# Out:
# True

# %%
name.endswith(" pune ")
# Out:
# True

# %%
name.endswith("e")
# Out:
# False

# %%
name.lstrip()
# Out:
# 'pune '

# %%
name.rstrip()
# Out:
# ' pune'

# %%
name.strip()
# Out:
# 'pune'

# %%
len(name)
# Out:
# 6

# %%
name.replace('u','oo')
# Out:
# ' poone '

# %% [markdown]
# # Operators

# %% [markdown]
# # arithmetic

# %%
a=5
b=17

# %%
a+b
# Out:
# 22

# %%
a-b
# Out:
# -12

# %%
b/a
# Out:
# 3.4

# %%
a*b
# Out:
# 85

# %%
a ** b # raise to
# Out:
# 762939453125

# %%
b//a #floor division
# Out:
# 3

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z+3
z
# Out:
# 8

# %%
z+=3
z
# Out:
# 11

# %%
z -=3
z
# Out:
# 8

# %%
z *=3

# %% [markdown]
# # comparison

# %%
a
# Out:
# 5

# %%
b
# Out:
# 17

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >=b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %% [markdown]
# # logical operator

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %% [markdown]
# # identity operator -> is, is not

# %%
a=5
b=5

# %%
id(a),id(b)
# Out:
# (140715070497832, 140715070497832)

# %%
a is b
# Out:
# True

# %%
a = [3,4]
b= [3,4]

# %%
a is b
# Out:
# False

# %%
id(a),id(b)
# Out:
# (2666721520128, 2666721916544)

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)
a
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %% [markdown]
# # membership selection operator -> in

# %%
l=[4,6,19,10]

# %%
6 in l
# Out:
# True

# %%
2 not in l
# Out:
# True

# %% [markdown]
# ## Precedence and association

# %%
# BODMAS

# %%
5+2-10
# Out:
# -3

# %%
(4-2)**2
# Out:
# 4

# %%
2 ** 2**3 # right association
# Out:
# 256

# %%
2**3//2
# Out:
# 4

# %% [markdown]
# # print function

# %%
name ="Shivam"
marks = 76.57

# %%
# my name is shiv and marks are 76.57

# %%
print ("my name is",name,' and marks are',marks)
# Out:
# my name is Shivam  and marks are 76.57

# %%
print("my name is %s and marks are %i"%(name,marks))
# Out:
# my name is Shivam and marks are 76

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Shivam and marks are 76.57

# %% [markdown]
# # dir and help

# %%
name
# Out:
# 'Shivam'

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
help(name.isupper)
# Out:
# Help on built-in function isupper:
#
# isupper() method of builtins.str instance
#     Return True if the string is an uppercase string, False otherwise.
#
#     A string is uppercase if all cased characters in the string are uppercase and
#     there is at least one cased character in the string.

# %% [markdown]
# # ascii

# %%
ord("a") # it returns ascii value of "a"
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
chr(35)
# Out:
# '#'

# %% [markdown]
# # type casting

# %%
num1 =34
num2=44.56
num3="ok"

# %%
type(num1)
# Out:
# int

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num2)
# Out:
# '44.56'

# %%
str(num1)
# Out:
# '34'

# %%
int("ok")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 int("ok")
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[205], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %% [markdown]
# # user input

# %%
a=int(input("Enter the numbrr"))
# Out:
# Enter the numbrr 78

# %%
print("ok")
# Out:
# ok

# %%
# write a program for addition of 2 numbers using user input

# %%
a = int(input("enter the number"))
b = int(input("enter the number"))
c= a+b
print("Addition is =>",c)
# Out:
# enter the number 4
# enter the number 5
# Addition is => 9

# %%
"""
read the time in second as user input
and print the time in format as hour:minutes:seconds

eg ...
input -> 125 seconds
output -> 00:02:056
"""
# Out:
# '\nread the time in second as user input\nand print the time in format as hour:minutes:seconds\n\neg ...\ninput -> 125 seconds\noutput -> 00:02:056\n'

# %%
sec=int(input("Enter thr time sec:"))
hours = sec // 3600
minutes =(sec%3600)//60
seconds=sec %60
print(f"{hours}:{minutes:}:{seconds}")
# Out:
# Enter thr time sec: 125
# 0:2:5
